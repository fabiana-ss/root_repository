# %% [markdown]
# # Projeto Final - Reconhecimento Facial para Controle de Acesso
#
# Aluno: Fabiana Santos da Silva
#
# Este projeto apresenta uma aplicação simples de Inteligência Artificial utilizando reconhecimento facial para simular um sistema de controle de acesso.
#
# A aplicação recebe uma imagem de entrada, compara com uma imagem de referência cadastrada e retorna uma decisão de acesso autorizado ou negado.

# %% [markdown]
# ## Contextualização
#
# Empresas precisam controlar o acesso a áreas restritas garantindo que apenas pessoas autorizadas possam entrar.
#
# Neste projeto será utilizado reconhecimento facial como uma ferramenta de apoio para comparar características faciais e auxiliar na decisão de liberar ou bloquear um acesso.
#
# O sistema será desenvolvido apenas para fins educacionais.

# %%
# Instalação do DeepFace (executar apenas no Google Colab)
# !pip install deepface

# Importação das bibliotecas

from deepface import DeepFace
import matplotlib.pyplot as plt
from PIL import Image
import os
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.7/170.7 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 60.9 MB/s eta 0:00:00
# ...
# 26-06-18 00:21:34 - Directory /root/.deepface has been created
# 26-06-18 00:21:34 - Directory /root/.deepface/weights has been created

# %% [markdown]
# ## Carregamento das imagens
#
# Nesta etapa serão enviadas as imagens utilizadas no teste.
#
# A primeira imagem representa uma pessoa cadastrada no sistema e a segunda representa a tentativa de acesso.
#
# As imagens utilizadas são apenas para teste e devem possuir autorização de uso.

# %%
# Importando ferramenta de upload do Google Colab

from google.colab import files

print("Envie a imagem da pessoa autorizada:")
upload1 = files.upload()


print("Agora envie a imagem de teste:")
upload2 = files.upload()
# Out:
# Envie a imagem da pessoa autorizada:
#      <input type="file" id="files-62064f56-2d6a-421e-b0b4-d14fcc1c87df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62064f56-2d6a-421e-b0b4-d14fcc1c87df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# Pegando automaticamente o nome dos arquivos enviados

imagem_referencia = list(upload1.keys())[0]

imagem_teste = list(upload2.keys())[0]


print("Imagem cadastrada:", imagem_referencia)

print("Imagem de teste:", imagem_teste)

# %%
# Exibindo as imagens

fig, imagens = plt.subplots(1,2, figsize=(10,5))


img1 = Image.open(imagem_referencia)

img2 = Image.open(imagem_teste)


imagens[0].imshow(img1)
imagens[0].set_title("Imagem cadastrada")
imagens[0].axis("off")


imagens[1].imshow(img2)
imagens[1].set_title("Imagem de entrada")
imagens[1].axis("off")


plt.show()

# %% [markdown]
# ## Fluxo de Trabalho do Sistema de Reconhecimento Facial
#
# O funcionamento da aplicação segue algumas etapas principais. Primeiro é realizado o cadastro da imagem de referência, que representa uma pessoa autorizada no sistema. Depois, uma nova imagem é recebida como tentativa de acesso.
#
# A Inteligência Artificial realiza a comparação entre as duas imagens, analisando características faciais e calculando o nível de similaridade.
#
# Com base nesse resultado, o sistema gera uma decisão informando se o acesso será autorizado ou negado.
#
# Fluxo:
#
# Cadastro da imagem autorizada
#
# ↓
#
# Armazenamento da imagem de referência
#
# ↓
#
# Captura da imagem de tentativa de acesso
#
# ↓
#
# Processamento da imagem utilizando DeepFace
#
# ↓
#
# Comparação das características faciais
#
# ↓
#
# Análise do resultado da similaridade
#
# ↓
#
# Decisão do sistema:
#
# - Semelhança encontrada → Acesso autorizado
# - Semelhança não encontrada → Acesso negado
#
# ↓
#
# Apresentação do resultado ao usuário

# %% [markdown]
# # Fluxo de Funcionamento da Aplicação
#
# A aplicação de reconhecimento facial segue um fluxo dividido em etapas. Primeiro é realizada a inclusão da imagem de uma pessoa autorizada, que será utilizada como referência. Depois, uma nova imagem é recebida como tentativa de acesso.
#
# A Inteligência Artificial realiza a análise das características faciais utilizando o DeepFace, compara as imagens e gera um resultado de similaridade. A partir desse resultado, o sistema toma uma decisão informando se o acesso será autorizado ou negado.
#
# ## Representação visual do fluxo

# %% [markdown]
#     IMAGEM CADASTRADA
#     (Pessoa autorizada)
#             |
#             |
#             v
#  Base de referência do sistema
#             |
#             |
#             v
#
#     IMAGEM DE ENTRADA
#    (Tentativa de acesso)
#             |
#             |
#             v
#
#     Processamento com IA
#       (DeepFace)
#             |
#             |
#             v
#
#  Comparação das características
#          faciais
#             |
#             |
#             v
#
#     Resultado da comparação
#
#             |
#     ---------------------
#     |                   |

# %% [markdown]
#    Semelhança encontrada Semelhança não encontrada
#     |                   |
#
#     v                   v

# %% [markdown]
# Acesso autorizado Acesso negado

# %% [markdown]
#     |                   |

# %% [markdown]
#    Liberação da entrada Bloqueio da entrada
#
#
#     |                   |

# %% [markdown]
# Esse fluxo representa o funcionamento básico de um sistema de controle de acesso utilizando reconhecimento facial, desde o cadastro da referência até a decisão final gerada pela Inteligência Artificial.

# %%
# Fluxo simples do controle de acesso

# Verifica o resultado da comparação facial

if resultado["verified"]:

    print("Pessoa reconhecida")
    print("Acesso autorizado")

else:

    print("Pessoa não reconhecida")
    print("Acesso negado")

# %% [markdown]
# Esse código representa a etapa final do sistema, onde o resultado gerado pela Inteligência Artificial é transformado em uma decisão de controle de acesso.
